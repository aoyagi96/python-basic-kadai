# %%
area = (10 + 20) * 5 / 2
print(str(area) + "㎠")
# Out:
# 'Python 3.11.2' でセルを実行するには、 ipykernel パッケージが必要です。
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Python 環境の作成</a> および必要なパッケージ。
#
# または、次のコマンドを使用して 'ipykernel' をインストールします: 'c:/Users/aoyag/AppData/Local/Programs/Python/Python311/python.exe -m pip install ipykernel -U --user --force-reinstall'
